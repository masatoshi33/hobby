# %%
import matplotlib.pyplot as plt
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout
 
num_classes = 10
im_rows = 32
im_cols = 32
im_size = im_rows * im_cols * 3
 
# データを読み込む
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
 
# データを一次元配列に変換 
X_train = X_train.reshape(-1, im_size).astype('float32') / 255
X_test = X_test.reshape(-1, im_size).astype('float32') / 255
# ラベルデータをOne-Hot形式に変換
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
 
# モデルを定義
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(im_size,)))
model.add(Dense(num_classes, activation='softmax'))
 
# モデルをコンパイル
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy'])
 
# 学習を実行
hist = model.fit(X_train, y_train,
    batch_size=32, epochs=50,
    verbose=1,
    validation_data=(X_test, y_test))
 
# モデルを評価
score = model.evaluate(X_test, y_test, verbose=1)
print('正解率=', score[1], 'loss=', score[0])
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.8993 - accuracy: 0.3252 - val_loss: 1.7543 - val_accuracy: 0.3735
# Epoch 2/50
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.7105 - accuracy: 0.3869 - val_loss: 1.6900 - val_accuracy: 0.3964
# Epoch 3/50
# 1563/1563 [==============================] - 29s 19ms/step - loss: 1.6448 - accuracy: 0.4133 - val_loss: 1.6544 - val_accuracy: 0.4173
# Epoch 4/50
# 1563/1563 [==============================] - 29s 19ms/step - loss: 1.5971 - accuracy: 0.4304 - val_loss: 1.5697 - val_accuracy: 0.4466
# Epoch 5/50
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.5628 - accuracy: 0.4433 - val_loss: 1.5894 - val_accuracy: 0.4321
# Epoch 6/50
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.5447 - accuracy: 0.4494 - val_loss: 1.5703 - val_accuracy: 0.4411
# Epoch 7/50
# ...

# %%
import numpy as np
# cifar-10 : (60000, 32, 32), (60000)
# cifar-100 : (60000, 32, 32), (60000)
# X_test : (10000, 32, 32)
# Y_test : (10000, 10)
print(X_test.shape)
print(y_test.shape)
y_test0 = np.full((10000, 10), 0.1)
score0 = model.evaluate(X_test, y_test0, verbose = 1)
print(score2)
# Out:
# (10000, 3072)
# (10000, 10)
# 313/313 [==============================] - 1s 4ms/step - loss: 4.2577 - accuracy: 0.1158
# [4.257654666900635, 0.11580000072717667]

# %%
from keras.datasets import cifar100
(X_train2, y_train2), (X_test2, y_test2) = cifar100.load_data()
 
# データを一次元配列に変換 
X_train2 = X_train2.reshape(-1, im_size).astype('float32') / 255
X_test2 = X_test2.reshape(-1, im_size).astype('float32') / 255
# ラベルデータをOne-Hot形式に変換
num_classes2 = 100
y_train2 = keras.utils.to_categorical(y_train2, num_classes2)
y_test2 = keras.utils.to_categorical(y_test2, num_classes2)

# %%
score2 = model.evaluate(X_test2, y_test0, verbose = 1)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 4.0516 - accuracy: 0.1198
